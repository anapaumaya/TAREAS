# %%
POO_AEROLINEAS= { " Delta" : [95,17,66,20,100,97,77,98,24,47],
         "Qatar" : [92,16,60,21,18,88,86,46,90,30],
          "AeroMexico": [92,29,17,77,21,11,91,82,73,44],
          "VivaAerobus" : [93,15,58,21,23,85,56,67,81,22],
          "Emirates": [90,17,27,19,92,40,68,87,10,25],
          "Air Canada": [92,75,21,16,77,64,42,39,93,97],
          "Alaskan Airlanes": [9,33,62,57,26,81,60,55,30,91],
          "Volaris":[20,4,78,62,56,49,52,66,53,80],
          "Iberia":[11,30,23,74,68,82,70,47,73,12],
          "AirFrance":[100,96,82,77,45,50,37,78,11,20]}

# %%
print(POO_AEROLINEAS)
# Out:
# {' Delta': [95, 17, 66, 20, 100, 97, 77, 98, 24, 47], 'Qatar': [92, 16, 60, 21, 18, 88, 86, 46, 90, 30], 'AeroMexico': [92, 29, 17, 77, 21, 11, 91, 82, 73, 44], 'VivaAerobus': [93, 15, 58, 21, 23, 85, 56, 67, 81, 22], 'Emirates': [90, 17, 27, 19, 92, 40, 68, 87, 10, 25], 'Air Canada': [92, 75, 21, 16, 77, 64, 42, 39, 93, 97], 'Alaskan Airlines': [9, 33, 62, 57, 26, 81, 60, 55, 30, 91], 'Volaris': [20, 4, 78, 62, 56, 49, 52, 66, 53, 80], 'Iberia': [11, 30, 23, 74, 68, 82, 70, 47, 73, 12], 'AirFrance': [100, 96, 82, 77, 45, 50, 37, 78, 11, 20]}

# %%
#Importamos al módulo Pandas
import pandas as pd

# %%
Aerolineas= pd.DataFrame(POO_AEROLINEAS)
Aerolineas
# Out:
#     Delta  Qatar  AeroMexico  VivaAerobus  Emirates  Air Canada  \
# 0      95     92          92           93        90          92
# 1      17     16          29           15        17          75
# 2      66     60          17           58        27          21
# 3      20     21          77           21        19          16
# 4     100     18          21           23        92          77
# 5      97     88          11           85        40          64
# 6      77     86          91           56        68          42
# 7      98     46          82           67        87          39
# 8      24     90          73           81        10          93
# 9      47     30          44           22        25          97
#
#    Alaskan Airlines  Volaris  Iberia  AirFrance
# 0                 9       20      11        100
# 1                33        4      30         96
# 2                62       78      23         82
# 3                57       62      74         77
# ...

# %%
type(Aerolineas)
# Out:
# pandas.core.frame.DataFrame

# %%
Aerolineas.ndim #Dimensiones como objeto en Pyhton
# Out:
# 2

# %%
Aerolineas["Qatar"]
# Out:
# 0    92
# 1    16
# 2    60
# 3    21
# 4    18
# 5    88
# 6    86
# 7    46
# 8    90
# 9    30
# Name: Qatar, dtype: int64

# %%
type(Aerolineas)
# Out:
# pandas.core.frame.DataFrame

# %%
Aerolineas[["Emirates","AeroMexico"]]
# Out:
#    Emirates  AeroMexico
# 0        90          92
# 1        17          29
# 2        27          17
# 3        19          77
# 4        92          21
# 5        40          11
# 6        68          91
# 7        87          82
# 8        10          73
# 9        25          44
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Emirates'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
Aerolineas.iloc[0:3] #Rebana la base de datos del primer renglón
                  # al segundo
# Out:
#     Delta  Qatar  AeroMexico  VivaAerobus  Emirates  Air Canada  \
# 0      95     92          92           93        90          92
# 1      17     16          29           15        17          75
# 2      66     60          17           58        27          21
#
#    Alaskan Airlines  Volaris  Iberia  AirFrance
# 0                 9       20      11        100
# 1                33        4      30         96
# 2                62       78      23         82
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...
